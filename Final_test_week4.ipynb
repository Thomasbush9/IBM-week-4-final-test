# %% [markdown]
# #  My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Thomas Wyndham Bush**
# Student

# %% [markdown]
# *I am interested in data science because I would like to become a researcher in the neuroscience's field.*

# %% [markdown]
# ### A simple function for divisions:

# %%
def divide(n1, n2):
  return n1 / n2

divide(10, 2)

# %% [markdown]
# [Marcus Aurelius Meditations](http://classics.mit.edu/Antoninus/meditations.html)
# **Birth and death date of Marcus Aurelius:**
# >It is not death that a man should fear, but he should fear never beginning to live (Marcus Aurelius).
# 1. 121 CE
# 2. 180 CE
